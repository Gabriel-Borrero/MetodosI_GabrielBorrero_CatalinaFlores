# %%
import numpy as np
import sympy as sym
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
from tqdm import tqdm
# Out:
# <style>.container { width:90% !important; }</style>

# %%
x = sym.Symbol('x',real=True)
y = sym.Symbol('y',real=True)
Dx = lambda f,x,y,h=1e-5: (f(x+h,y) - f(x-h,y))/(2*h)
Dy = lambda f,x,y,h=1e-5: (f(x,y+h) - f(x,y-h))/(2*h)
Gradient = lambda f,x,y: np.array([Dx(f,x,y),Dy(f,x,y)])

# %%
def f3(x,y):
    return np.abs(x-2)

# %%
def Minimizer(f, N = 100, gamma = 0.01):
    
    r = np.zeros((N,2))
    r[0] = np.random.uniform(-5.,5.,size=2)
    
    Grad = np.zeros((N,2))
    Grad[0] = Gradient(f,r[0,0],r[0,1])
    
    # We save the gradient in each step

    for i in tqdm(range(1,N)):
        r[i] = r[i-1] - gamma*Gradient(f,r[i-1,0],r[i-1,1])
        Grad[i] = Gradient(f,r[i-1,0],r[i-1,1])
        
        
    return r,Grad

# %%
r3,Grad3 = Minimizer(f3)
# Out:
# 100%|██████████| 99/99 [00:00<00:00, 12364.84it/s]

# %%
r3
# Out:
# array([[-1.96552613, -0.5309597 ],
#        [-1.95552613, -0.5309597 ],
#        [-1.94552613, -0.5309597 ],
#        [-1.93552613, -0.5309597 ],
#        [-1.92552613, -0.5309597 ],
#        [-1.91552613, -0.5309597 ],
#        [-1.90552613, -0.5309597 ],
#        [-1.89552613, -0.5309597 ],
#        [-1.88552613, -0.5309597 ],
#        [-1.87552613, -0.5309597 ],
#        [-1.86552613, -0.5309597 ],
#        [-1.85552613, -0.5309597 ],
#        [-1.84552613, -0.5309597 ],
#        [-1.83552613, -0.5309597 ],
#        [-1.82552613, -0.5309597 ],
#        [-1.81552613, -0.5309597 ],
#        [-1.80552613, -0.5309597 ],
#        [-1.79552613, -0.5309597 ],
#        [-1.78552613, -0.5309597 ],
#        [-1.77552613, -0.5309597 ],
#        [-1.76552613, -0.5309597 ],
#        [-1.75552613, -0.5309597 ],
#        [-1.74552613, -0.5309597 ],
#        [-1.73552613, -0.5309597 ],
#        [-1.72552613, -0.5309597 ],
#        [-1.71552613, -0.5309597 ],
#        [-1.70552613, -0.5309597 ],
#        [-1.69552613, -0.5309597 ],
#        [-1.68552613, -0.5309597 ],
#        [-1.67552613, -0.5309597 ],
#        [-1.66552613, -0.5309597 ],
#        [-1.65552613, -0.5309597 ],
#        [-1.64552613, -0.5309597 ],
#        [-1.63552613, -0.5309597 ],
#        [-1.62552613, -0.5309597 ],
#        [-1.61552613, -0.5309597 ],
#        [-1.60552613, -0.5309597 ],
#        [-1.59552613, -0.5309597 ],
#        [-1.58552613, -0.5309597 ],
#        [-1.57552613, -0.5309597 ],
#        [-1.56552613, -0.5309597 ],
#        [-1.55552613, -0.5309597 ],
#        [-1.54552613, -0.5309597 ],
#        [-1.53552613, -0.5309597 ],
#        [-1.52552613, -0.5309597 ],
#        [-1.51552613, -0.5309597 ],
#        [-1.50552613, -0.5309597 ],
#        [-1.49552613, -0.5309597 ],
#        [-1.48552613, -0.5309597 ],
#        [-1.47552613, -0.5309597 ],
#        [-1.46552613, -0.5309597 ],
#        [-1.45552613, -0.5309597 ],
#        [-1.44552613, -0.5309597 ],
#        [-1.43552613, -0.5309597 ],
#        [-1.42552613, -0.5309597 ],
#        [-1.41552613, -0.5309597 ],
#        [-1.40552613, -0.5309597 ],
#        [-1.39552613, -0.5309597 ],
#        [-1.38552613, -0.5309597 ],
#        [-1.37552613, -0.5309597 ],
#        [-1.36552613, -0.5309597 ],
#        [-1.35552613, -0.5309597 ],
#        [-1.34552613, -0.5309597 ],
#        [-1.33552613, -0.5309597 ],
#        [-1.32552613, -0.5309597 ],
#        [-1.31552613, -0.5309597 ],
#        [-1.30552613, -0.5309597 ],
#        [-1.29552613, -0.5309597 ],
#        [-1.28552613, -0.5309597 ],
#        [-1.27552613, -0.5309597 ],
#        [-1.26552613, -0.5309597 ],
#        [-1.25552613, -0.5309597 ],
#        [-1.24552613, -0.5309597 ],
#        [-1.23552613, -0.5309597 ],
#        [-1.22552613, -0.5309597 ],
#        [-1.21552613, -0.5309597 ],
#        [-1.20552613, -0.5309597 ],
#        [-1.19552613, -0.5309597 ],
#        [-1.18552613, -0.5309597 ],
#        [-1.17552613, -0.5309597 ],
#        [-1.16552613, -0.5309597 ],
#        [-1.15552613, -0.5309597 ],
#        [-1.14552613, -0.5309597 ],
#        [-1.13552613, -0.5309597 ],
#        [-1.12552613, -0.5309597 ],
#        [-1.11552613, -0.5309597 ],
#        [-1.10552613, -0.5309597 ],
#        [-1.09552613, -0.5309597 ],
#        [-1.08552613, -0.5309597 ],
#        [-1.07552613, -0.5309597 ],
#        [-1.06552613, -0.5309597 ],
#        [-1.05552613, -0.5309597 ],
#        [-1.04552613, -0.5309597 ],
#        [-1.03552613, -0.5309597 ],
#        [-1.02552613, -0.5309597 ],
#        [-1.01552613, -0.5309597 ],
#        [-1.00552613, -0.5309597 ],
#        [-0.99552613, -0.5309597 ],
#        [-0.98552613, -0.5309597 ],
#        [-0.97552613, -0.5309597 ]])

# %% [markdown]
# Podemos decir que no se puede minimizar la función debido a que el gradiente no cambia. Esto quiere decir que la función converge y, por lo tanto, ya alcanzó el mínimo.
